# %%
import sys
sys.path.insert(0, "/home/users/bensonb/international-brain-lab/prior-localization/brainwide/decoding")
sys.path.insert(0, "/home/users/bensonb/international-brain-lab/prior-localization/brainwide/decoding/functions")
import functions

# %%
sys.path
# Out:
# ['/home/users/bensonb/international-brain-lab/prior-localization/brainwide/decoding/functions',
#  '/home/users/bensonb/international-brain-lab/prior-localization/brainwide/decoding',
#  '~/international-brain-lab/prior-localization/brainwide/decoding/functions',
#  '~/international-brain-lab/prior-localization/brainwide/decoding',
#  '~/international-brain-lab/prior-localization/brainwide/decoding/functions/',
#  '~/international-brain-lab/prior-localization/brainwide/decoding/',
#  '/home/users/bensonb/international-brain-lab/prior-localization/brainwide/decoding/pipelines',
#  '/home/users/bensonb/mambaforge/envs/iblenv/lib/python39.zip',
#  '/home/users/bensonb/mambaforge/envs/iblenv/lib/python3.9',
#  '/home/users/bensonb/mambaforge/envs/iblenv/lib/python3.9/lib-dynload',
#  '',
#  '/home/users/bensonb/.local/lib/python3.9/site-packages',
#  '/home/users/bensonb/mambaforge/envs/iblenv/lib/python3.9/site-packages',
#  '/home/users/bensonb/international-brain-lab/ibllib-repo',
#  '/home/users/bensonb/international-brain-lab/iblapps',
#  '/home/users/bensonb/international-brain-lab/analysis',
#  '/home/users/bensonb/international-brain-lab/IBL-pipeline',
#  '/home/users/bensonb/international-brain-lab/phy',
#  '/home/users/bensonb/international-brain-lab/phylib']
